# %% [markdown]
# # 📊 Chapter 1: Basic Distribution

# %% [markdown]
# **Overview:** This section explores ... (Edit with specific goals and observations)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

 
data = pd.read_csv('survey_v2.csv')
data = data.drop(columns='q4')
# data = data.drop(columns='Unnamed: NaN')
# print(data)
result = data.head(10)
print(result)
# davie = pd.DataFrame(data=sammie_df)
# davie.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 7 data = pd.read_csv('survey_v2.csv')
#       8 data = data.drop(columns='q4')
#       9 # data = data.drop(columns='Unnamed: NaN')
#      10 # print(data)
#
# ...

# %%
# Distribution of Course of Study
result['q1'].value_counts(dropna=False).plot(kind='bar', color='skyblue')
plt.title("Course of Study")
plt.xlabel("Course of Study")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:** (e.g., Students who... Edit this based on results)

# %% [markdown]
# # 🔄 Chapter 2: Correlation & Pattern Discovery

# %% [markdown]
# **Overview:** This section explores ... (Edit with specific goals and observations)

# %%
# Distribution of Living Situation
result['q3'].value_counts(dropna=False).plot(kind='bar', color='skyblue')
plt.title("Living Situation")
plt.xlabel("Living Situation")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Distribution of Preferred Programming Language
result['q8'].value_counts(dropna=False).plot(kind='bar', color='skyblue')
plt.title("Preferred Programming Language")
plt.xlabel("Preferred Programming Language")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:** (e.g., Students who... Edit this based on results)

# %% [markdown]
# # 🧩 Chapter 3: Clustering Students

# %% [markdown]
# **Overview:** This section explores ... (Edit with specific goals and observations)

# %%
# Distribution of Time Spent Studying (Weekends)
result['q6'].value_counts(dropna=False).plot(kind='bar', color='skyblue')
plt.title("Time Spent Studying (Weekends)")
plt.xlabel("Time Spent Studying (Weekends)")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Distribution of Online Learning Platform
result['q9'].value_counts(dropna=False).plot(kind='bar', color='skyblue')
plt.title("Online Learning Platform")
plt.xlabel("Online Learning Platform")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:** (e.g., Students who... Edit this based on results)

# %% [markdown]
# # 🧠 Chapter 4: Classification

# %% [markdown]
# **Overview:** This section explores ... (Edit with specific goals and observations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from mlxtend.frequent_patterns import apriori, association_rules

# Load dataset
df = pd.read_csv("survey_v2.csv")

# Fill missing values for simplicity
df.fillna("Unknown", inplace=True)

# Encode categorical columns for clustering and classification
label_cols = ['q1', 'q2', 'q3', 'q5', 'q6', 'q8', 'q9', 'q30', 'q35']
df_encoded = df[label_cols].apply(LabelEncoder().fit_transform)

# %%
# Correlation heatmap between encoded categorical values
plt.figure(figsize=(10,6))
sns.heatmap(df_encoded.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:** (e.g., Students who... Edit this based on results)

# %% [markdown]
# # 🔗 Chapter 5: Association Rule Mining & Conclusion

# %% [markdown]
# **Overview:** This section explores ... (Edit with specific goals and observations)

# %%
# KMeans clustering with 3 clusters
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_encoded)
kmeans = KMeans(n_clusters=3, random_state=42)
df_encoded['cluster'] = kmeans.fit_predict(X_scaled)

# PCA for visualization
pca = PCA(n_components=2)
components = pca.fit_transform(X_scaled)
df_encoded['pc1'] = components[:,0]
df_encoded['pc2'] = components[:,1]

# Plot clusters
sns.scatterplot(data=df_encoded, x='pc1', y='pc2', hue='cluster', palette='Set1')
plt.title("KMeans Clustering Visualization")
plt.tight_layout()
plt.show()

# %%
# Predict career aspiration from study habits and preferences
X = df_encoded.drop(columns=['q30'])
y = df_encoded['q30']  # target: career aspiration (encoded)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = DecisionTreeClassifier(max_depth=4)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("Classification Report (Predicting Career Aspiration):")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report (Predicting Career Aspiration):
# c:\Users\Samuel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Samuel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# Simple one-hot encoding for association rules
df_assoc = pd.get_dummies(df[['q1', 'q2', 'q3', 'q5', 'q6', 'q8', 'q9', 'q30']])

# Generate frequent itemsets
frequent_items = apriori(df_assoc, min_support=0.1, use_colnames=True)

# Generate rules
rules = association_rules(frequent_items, metric="lift", min_threshold=1.1)
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head()
# Out:
#                          antecedents                        consequents  \
# 0                           (q2_CSE)                        (q1_B.Tech)
# 1                        (q1_B.Tech)                           (q2_CSE)
# 2                           (q2_CSE)  (q30_Software/ Website Developer)
# 3  (q30_Software/ Website Developer)                           (q2_CSE)
# 4                       (q2_Unknown)                          (q5_1 hr)
#
#     support  confidence      lift
# 0  0.248031    1.000000  1.209524
# 1  0.248031    0.300000  1.209524
# 2  0.106299    0.428571  1.432331
# 3  0.106299    0.355263  1.432331
# 4  0.118110    0.588235  1.185808

# %% [markdown]
# **Insights:** (e.g., Students who... Edit this based on results)
